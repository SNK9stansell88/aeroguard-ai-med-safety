# %% [markdown]
# # 01 — Medication Error Forecasting Baseline
#
# This notebook loads historical medication error data and builds a baseline forecast model.
# It follows step 1 of the pipeline: data → monthly counts → forecast.
